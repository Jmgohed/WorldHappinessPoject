# %%
import pandas as pd
import numpy as np
import seaborn as snsi
import numpy as np
import pandas as pd
import seaborn as sns

# %%
WHR2015 = pd.read_csv(r'C:\Users\Jonathan\Desktop\Data Science workbench\FINAL Project 2\Dataset\2015.csv')

# %%
WHR2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
WHSasa = pd.read_csv(r'C:\Users\Jonathan\Desktop\Data Science workbench\FINAL Project 2\Dataset\alcoholSubstanceAbuse.csv')
WHSalbss = pd.read_csv(r'C:\Users\Jonathan\Desktop\Data Science workbench\FINAL Project 2\Dataset\atLeastBasicSanitizationServices.csv')
WHSbdws = pd.read_csv(r'C:\Users\Jonathan\Desktop\Data Science workbench\FINAL Project 2\Dataset\basicDrinkingWaterServices.csv')
WHScfat = pd.read_csv(r'C:\Users\Jonathan\Desktop\Data Science workbench\FINAL Project 2\Dataset\cleanFuelAndTech.csv')
WHScsr = pd.read_csv(r'C:\Users\Jonathan\Desktop\Data Science workbench\FINAL Project 2\Dataset\crudeSuicideRates.csv')
WHSimr = pd.read_csv(r'C:\Users\Jonathan\Desktop\Data Science workbench\FINAL Project 2\Dataset\infantMortalityRate.csv')
WHSleab = pd.read_csv(r'C:\Users\Jonathan\Desktop\Data Science workbench\FINAL Project 2\Dataset\lifeExpectancyAtBirth.csv')

# %%
WHSasa.head()
# Out:
#       Location  Period                                          Indicator  \
# 0  Afghanistan    2018  Total (recorded+unrecorded) alcohol per capita...
# 1  Afghanistan    2018  Total (recorded+unrecorded) alcohol per capita...
# 2  Afghanistan    2018  Total (recorded+unrecorded) alcohol per capita...
# 3  Afghanistan    2015  Total (recorded+unrecorded) alcohol per capita...
# 4  Afghanistan    2015  Total (recorded+unrecorded) alcohol per capita...
#
#          Dim1  First Tooltip
# 0  Both sexes          0.210
# 1        Male          0.360
# 2      Female          0.055
# 3  Both sexes          0.210
# 4        Male          0.350

# %%
columns = pd.DataFrame(WHR2018, columns)

# %%
WHRmerge = pd.merge(2019, 2018)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-e3d3edccf6ea> in <module>
# ----> 1 WHRmerge = pd.merge(2019, 2018)
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      71     validate=None,
#      72 ) -> "DataFrame":
# ---> 73     op = _MergeOperation(
#      74         left,
#      75         right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     569         validate=None,
#     570     ):
# --> 571         _left = _validate_operand(left)
#     572         _right = _validate_operand(right)
#     573         self.left = self.orig_left = _left
#
# ...
